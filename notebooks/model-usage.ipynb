# %% [markdown]
# # Development

# %%
from dotenv import load_dotenv
from os import getenv
from src.data.util import by_group
from src.util.logger import write_data_config, read_data_config
import json
from src.util.inference import (
    parse_label_fields,
    compute_per_label_metrics,
    parse_inference,
    compute_match_statistics,
    print_match_statistics,
    print_per_label_metrics,
)

# %%
load_dotenv()
# Out:
# True

# %%
filename = getenv("dataset", "")
config = "../config.yaml"  # getenv("config", "../config.yaml")

schemas = read_data_config(config)

# print(schemas)
# print(schemas["all"])

feature = schemas["all"]["feature"]
target = [schemas["all"]["target"][i::6] for i in range(6)]
schemas["by_group"] = schemas["all"].copy()
schemas["by_group"]["target"] = target

# write_data_config("by_group", schemas["by_group"], config)
# print(schemas)

# import by_group
# print(by_group(filename)[1])

# %% [markdown]
# # Check inference statistics

# %%
json_path = "../outputs/inference/inference_results_20260324_155925.json"
print(f"Loading inference results from: {json_path}")
result = parse_inference(json_path)
print(f"Loaded {len(result)} samples")
# Out:
# Loading inference results from: ../outputs/inference/inference_results_20260324_155925.json
# Loaded 909 samples

# %% [markdown]
# Compute and print overall statistics

# %%
stats = compute_match_statistics(json_path)
print_match_statistics(stats)
# Out:
# ============================================================
# Match Statistics
# ============================================================
# Total samples: 909
# Top-k considered: 1
#
# Exact Match Rates:
#   Top-1: 4.73% (43/909)
#   Top-1: 4.73% (43/909)
#
# Score Statistics:
#   Average: 0.7103
#   Min: -0.1813
#   Max: 0.8776
#
# Field-Level Accuracy:
#   HxType1: 35.75%
#   Manufacturer1: 29.70%
#   NominelEffectEach1: 73.27%
#   Pieces1: 50.72%
#   SubType1: 58.42%
#   Year1: 45.10%
# ============================================================

# %%
metrics = compute_per_label_metrics(result)
print_per_label_metrics(metrics)
# Out:
# ================================================================================
# PER-LABEL METRICS
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# Field: HxType1
# ────────────────────────────────────────────────────────────────────────────────
# Accuracy: 35.75% (325/909)
#
# Ground Truth Value Distribution:
#   'Isoleret varmeveksler'                  :   553 ( 60.8%)
#   'Fjernvarmeveksler'                      :    90 (  9.9%)
#   ''                                       :    62 (  6.8%)
#   'Varmeveksler'                           :    54 (  5.9%)
#   'Uisoleret varmeveksler'                 :    45 (  5.0%)
#   'Isoleret pladevarmeveksler'             :    38 (  4.2%)
#   'Isoleret veksler'                       :    34 (  3.7%)
#   'Isoleret rørvarmeveksler'               :    19 (  2.1%)
#   'Isoleret rørveksler'                    :     3 (  0.3%)
#   'Isoleret pladeveksler'                  :     3 (  0.3%)
#
# Prediction Value Distribution:
#   'Isoleret varmeveksler'                  :   305 ( 33.6%)
#   'Isoleret pladevarmeveksler'             :   287 ( 31.6%)
#   'Isoleret fjernvarmeveksler'             :   106 ( 11.7%)
#   'Isoleret rørvarmeveksler'               :    97 ( 10.7%)
#   'Varmeveksler'                           :    77 (  8.5%)
#   'Uisoleret varmeveksler'                 :    23 (  2.5%)
#   ''                                       :     6 (  0.7%)
#   'Isoleret rørveksler'                    :     6 (  0.7%)
#   'Isoleret pladeveksler'                  :     1 (  0.1%)
#   'Fjernvarmeveksler'                      :     1 (  0.1%)
#
# Top 5 Most Common Errors:
#   1. GT: 'Isoleret varmeveksler'             → Pred: 'Isoleret pladevarmeveksler'        (count: 157)
#   2. GT: 'Fjernvarmeveksler'                 → Pred: 'Isoleret fjernvarmeveksler'        (count: 57)
#   3. GT: 'Isoleret varmeveksler'             → Pred: 'Isoleret rørvarmeveksler'          (count: 52)
#   4. GT: 'Isoleret varmeveksler'             → Pred: 'Varmeveksler'                      (count: 45)
#   5. GT: 'Varmeveksler'                      → Pred: 'Isoleret pladevarmeveksler'        (count: 34)
#
# ────────────────────────────────────────────────────────────────────────────────
# Field: Manufacturer1
# ────────────────────────────────────────────────────────────────────────────────
# Accuracy: 29.70% (270/909)
#
# Ground Truth Value Distribution:
#   'Unknown'                                :   576 ( 63.4%)
#   'Reci'                                   :    82 (  9.0%)
#   'Gemina Termix'                          :    40 (  4.4%)
#   'None - direct district heating'         :    31 (  3.4%)
#   'Sondex Teknik'                          :    31 (  3.4%)
#   'CTC'                                    :    28 (  3.1%)
#   'Reflex'                                 :    20 (  2.2%)
#   'Danfoss'                                :    16 (  1.8%)
#   'Danfoss Redan'                          :    12 (  1.3%)
#   'Elge'                                   :    10 (  1.1%)
#
# Prediction Value Distribution:
#   'Danfoss'                                :   259 ( 28.5%)
#   'Unknown'                                :   180 ( 19.8%)
#   'Gemina Termix'                          :   172 ( 18.9%)
#   'Reci'                                   :   121 ( 13.3%)
#   'CTC'                                    :    66 (  7.3%)
#   'Elge'                                   :    36 (  4.0%)
#   'Metro Therm'                            :    16 (  1.8%)
#   'Armatec'                                :    13 (  1.4%)
#   'Danfoss Redan'                          :    13 (  1.4%)
#   'Aga'                                    :     7 (  0.8%)
#
# Top 5 Most Common Errors:
#   1. GT: 'Unknown'                           → Pred: 'Danfoss'                           (count: 197)
#   2. GT: 'Unknown'                           → Pred: 'Reci'                              (count: 78)
#   3. GT: 'Unknown'                           → Pred: 'Gemina Termix'                     (count: 70)
#   4. GT: 'Unknown'                           → Pred: 'CTC'                               (count: 39)
#   5. GT: 'Sondex Teknik'                     → Pred: 'Gemina Termix'                     (count: 20)
#
# ────────────────────────────────────────────────────────────────────────────────
# Field: NominelEffectEach1
# ────────────────────────────────────────────────────────────────────────────────
# Accuracy: 73.27% (666/909)
#
# Ground Truth Value Distribution:
#   ''                                       :   838 ( 92.2%)
#   '1100 kW'                                :    23 (  2.5%)
#   '150 kW'                                 :     9 (  1.0%)
#   '700 kW'                                 :     6 (  0.7%)
#   '100 kW'                                 :     3 (  0.3%)
#   '400 kW'                                 :     3 (  0.3%)
#   '300 kW'                                 :     2 (  0.2%)
#   '226 kW'                                 :     2 (  0.2%)
#   '250 kW'                                 :     2 (  0.2%)
#   'After 1980'                             :     1 (  0.1%)
#
# Prediction Value Distribution:
#   ''                                       :   678 ( 74.6%)
#   '250 kW'                                 :   103 ( 11.3%)
#   '55 kW'                                  :    77 (  8.5%)
#   '150 kW'                                 :    18 (  2.0%)
#   '100 kW'                                 :    11 (  1.2%)
#   '700 kW'                                 :     9 (  1.0%)
#   '300 kW'                                 :     4 (  0.4%)
#   '1500 kW'                                :     2 (  0.2%)
#   '75 kW'                                  :     2 (  0.2%)
#   '37 kW'                                  :     1 (  0.1%)
#
# Top 5 Most Common Errors:
#   1. GT: ''                                  → Pred: '250 kW'                            (count: 102)
#   2. GT: ''                                  → Pred: '55 kW'                             (count: 67)
#   3. GT: '1100 kW'                           → Pred: ''                                  (count: 20)
#   4. GT: ''                                  → Pred: '100 kW'                            (count: 6)
#   5. GT: ''                                  → Pred: '150 kW'                            (count: 6)
#
# ────────────────────────────────────────────────────────────────────────────────
# Field: Pieces1
# ────────────────────────────────────────────────────────────────────────────────
# Accuracy: 50.72% (461/909)
#
# Ground Truth Value Distribution:
#   '1.0'                                    :   811 ( 89.2%)
#   '2.0'                                    :    75 (  8.3%)
#   '3.0'                                    :    18 (  2.0%)
#   '4.0'                                    :     4 (  0.4%)
#   '0.53'                                   :     1 (  0.1%)
#
# Prediction Value Distribution:
#   '1.0'                                    :   453 ( 49.8%)
#   '2.0'                                    :   447 ( 49.2%)
#   '4.0'                                    :     7 (  0.8%)
#   '3.0'                                    :     2 (  0.2%)
#
# Top 5 Most Common Errors:
#   1. GT: '1.0'                               → Pred: '2.0'                               (count: 389)
#   2. GT: '2.0'                               → Pred: '1.0'                               (count: 29)
#   3. GT: '3.0'                               → Pred: '2.0'                               (count: 11)
#   4. GT: '1.0'                               → Pred: '4.0'                               (count: 7)
#   5. GT: '3.0'                               → Pred: '1.0'                               (count: 6)
#
# Confusion Matrix (rows=GT, cols=Pred):
#              0.53         1.0         2.0         3.0         4.0
#  0.53           ·           1           ·           ·           ·
#   1.0           ·         414         389           1           7
#   2.0           ·          29          46           ·           ·
#   3.0           ·           6          11           1           ·
#   4.0           ·           3           1           ·           ·
#
# ────────────────────────────────────────────────────────────────────────────────
# Field: SubType1
# ────────────────────────────────────────────────────────────────────────────────
# Accuracy: 58.42% (531/909)
#
# Ground Truth Value Distribution:
#   ''                                       :   729 ( 80.2%)
#   'SL3323TLX'                              :    23 (  2.5%)
#   'SKR'                                    :    11 (  1.2%)
#   'Compactstation CSC213'                  :     8 (  0.9%)
#   'LP1400L-120'                            :     6 (  0.7%)
#   'SL140 1.90 95/45-70/40'                 :     3 (  0.3%)
#   'VT 60-III'                              :     3 (  0.3%)
#   'VX-2'                                   :     3 (  0.3%)
#   'SL140'                                  :     3 (  0.3%)
#   'OHC 60-40'                              :     3 (  0.3%)
#
# Prediction Value Distribution:
#   ''                                       :   528 ( 58.1%)
#   'Compactstation VX 65/50/28-E'           :   143 ( 15.7%)
#   'SL140TL-1/80-EE'                        :   103 ( 11.3%)
#   'Compactstation CSC213'                  :    18 (  2.0%)
#   'R-75'                                   :    15 (  1.7%)
#   'VXT 100 kW KBH Standard'                :    11 (  1.2%)
#   'BR-26'                                  :    11 (  1.2%)
#   'MD76-14'                                :    10 (  1.1%)
#   'XB70L'                                  :    10 (  1.1%)
#   'LP1400L-120'                            :     9 (  1.0%)
#
# Top 5 Most Common Errors:
#   1. GT: ''                                  → Pred: 'Compactstation VX 65/50/28-E'      (count: 90)
#   2. GT: ''                                  → Pred: 'SL140TL-1/80-EE'                   (count: 83)
#   3. GT: 'SL3323TLX'                         → Pred: 'Compactstation VX 65/50/28-E'      (count: 20)
#   4. GT: ''                                  → Pred: 'VXT 100 kW KBH Standard'           (count: 9)
#   5. GT: ''                                  → Pred: 'BR-26'                             (count: 9)
#
# ────────────────────────────────────────────────────────────────────────────────
# Field: Year1
# ────────────────────────────────────────────────────────────────────────────────
# Accuracy: 45.10% (410/909)
#
# Ground Truth Value Distribution:
#   ''                                       :   519 ( 57.1%)
#   'After 1980'                             :    85 (  9.4%)
#   '2017'                                   :    26 (  2.9%)
#   '1980'                                   :    14 (  1.5%)
#   '2000-2009'                              :    14 (  1.5%)
#   '2019'                                   :    12 (  1.3%)
#   'After 2020'                             :    11 (  1.2%)
#   '1996'                                   :    11 (  1.2%)
#   '1990-1999'                              :    11 (  1.2%)
#   '1987'                                   :    10 (  1.1%)
#
# Prediction Value Distribution:
#   ''                                       :   444 ( 48.8%)
#   '2019'                                   :   152 ( 16.7%)
#   '2023'                                   :   103 ( 11.3%)
#   '1990'                                   :    66 (  7.3%)
#   '1996'                                   :    22 (  2.4%)
#   '2021'                                   :    20 (  2.2%)
#   '1998'                                   :    19 (  2.1%)
#   '2015'                                   :    17 (  1.9%)
#   '2007'                                   :    12 (  1.3%)
#   '1993'                                   :    10 (  1.1%)
#
# Top 5 Most Common Errors:
#   1. GT: ''                                  → Pred: '2019'                              (count: 60)
#   2. GT: 'After 1980'                        → Pred: '2023'                              (count: 30)
#   3. GT: '2017'                              → Pred: '2019'                              (count: 22)
#   4. GT: ''                                  → Pred: '2023'                              (count: 22)
#   5. GT: ''                                  → Pred: '1990'                              (count: 22)
#
# ================================================================================
