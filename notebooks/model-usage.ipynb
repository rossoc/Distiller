# %% [markdown]
# # Data Exploration

# %%
from dotenv import load_dotenv
from os import getenv
from src.data.util import by_field
from src.util.logger import write_data_config, read_data_config

load_dotenv()


filename = getenv("dataset", "")
config = getenv("config", "")

schemas = read_data_config(config)
feature = schemas["all"]["feature"]
target = [schemas["all"]["target"][i::6] for i in range(6)]

schemas["by_group"] = {"feature": feature, "target": target}
# schemas = write_data_config(config)

# %%
print(config["all"])

# %%
i = []
print(by_field(filename))

# write_data_config(value, key, config)
